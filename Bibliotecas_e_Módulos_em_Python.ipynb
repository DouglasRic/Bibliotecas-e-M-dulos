# %% [markdown]
# <a href="https://colab.research.google.com/github/DouglasRic/Bibliotecas-e-M-dulos/blob/main/Bibliotecas_e_M%C3%B3dulos_em_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aula 4 – Bibliotecas e Módulos em Python

# Passo 1: Definindo a classe Livro
class Livro:
    def __init__(self, titulo, autor, genero, quantidade):
        self.titulo = titulo
        self.autor = autor
        self.genero = genero
        self.quantidade = quantidade

    def __str__(self):
        return f'Título: {self.titulo} | Autor: {self.autor} | Gênero: {self.genero} | Quantidade: {self.quantidade}'


# Passo 2: Criando a lista de livros5
biblioteca = []

# Passo 3: Funções para gerenciar os livros

# Cadastrar novo livro
def cadastrar_livro():
    titulo = input("Digite o título do livro: ")
    autor = input("Digite o autor do livro: ")
    genero = input("Digite o gênero do livro: ")
    quantidade = int(input("Digite a quantidade disponível: "))
    novo_livro = Livro(titulo, autor, genero, quantidade)
    biblioteca.append(novo_livro)
    print("📗 Livro cadastrado com sucesso!")

# Listar todos os livros
def listar_livros():
    if not biblioteca:
        print("Nenhum livro cadastrado.")
    else:
        print("\n📚 Lista de Livros:")
        for livro in biblioteca:
            print(livro)

# Buscar livro por título
def buscar_livro(titulo_procurado):
    encontrados = [livro for livro in biblioteca if livro.titulo.lower() == titulo_procurado.lower()]
    if encontrados:
        print("\n🔍 Livro(s) encontrado(s):")
        for livro in encontrados:
            print(livro)
    else:
        print("🚫 Livro não encontrado.")

# Passo 4: Gerar gráfico com Matplotlib
import matplotlib.pyplot as plt

def gerar_grafico_genero():
    if not biblioteca:
        print("Nenhum dado para gerar gráfico.")
        return

    generos = {}
    for livro in biblioteca:
        if livro.genero in generos:
            generos[livro.genero] += livro.quantidade
        else:
            generos[livro.genero] = livro.quantidade

    plt.figure(figsize=(10,5))
    plt.bar(generos.keys(), generos.values(), color='skyblue')
    plt.title("Quantidade de Livros por Gênero")
    plt.xlabel("Gênero")
    plt.ylabel("Quantidade")
    plt.grid(True)
    plt.show()

# Passo 5: Testar o sistema
# (Exemplo simples de menu interativo)

def menu():
    while True:
        print("\n--- MENU ---")
        print("1. Cadastrar Livro")
        print("2. Listar Livros")
        print("3. Buscar Livro por Título")
        print("4. Gerar Gráfico por Gênero")
        print("5. Sair")
        opcao = input("Escolha uma opção: ")

        if opcao == '1':
            cadastrar_livro()
        elif opcao == '2':
            listar_livros()
        elif opcao == '3':
            titulo = input("Digite o título do livro a buscar: ")
            buscar_livro(titulo)
        elif opcao == '4':
            gerar_grafico_genero()
        elif opcao == '5':
            print("Encerrando o sistema. Até mais! 👋")
            break
        else:
            print("Opção inválida. Tente novamente.")

# Para iniciar o sistema no Google Colab, basta rodar:
menu()
# Out:
# --- MENU ---
# 1. Cadastrar Livro
# 2. Listar Livros
# 3. Buscar Livro por Título
# 4. Gerar Gráfico por Gênero
# 5. Sair
# Escolha uma opção: 1
# Digite o título do livro: Duna
# Digite o autor do livro: Frank Herbert
# Digite o gênero do livro: Ficção científica
# Digite a quantidade disponível: 5
# 📗 Livro cadastrado com sucesso!
#
# --- MENU ---
# 1. Cadastrar Livro
# 2. Listar Livros
# 3. Buscar Livro por Título
# 4. Gerar Gráfico por Gênero
# 5. Sair
# Escolha uma opção: 2
#
# 📚 Lista de Livros:
# Título: Duna | Autor: Frank Herbert | Gênero: Ficção científica | Quantidade: 5
#
# --- MENU ---
# 1. Cadastrar Livro
# 2. Listar Livros
# 3. Buscar Livro por Título
# 4. Gerar Gráfico por Gênero
# 5. Sair
# Escolha uma opção: Duna
# Opção inválida. Tente novamente.
#
# --- MENU ---
# 1. Cadastrar Livro
# 2. Listar Livros
# 3. Buscar Livro por Título
# 4. Gerar Gráfico por Gênero
# 5. Sair
# Escolha uma opção: 4
# --- MENU ---
# 1. Cadastrar Livro
# 2. Listar Livros
# ...
